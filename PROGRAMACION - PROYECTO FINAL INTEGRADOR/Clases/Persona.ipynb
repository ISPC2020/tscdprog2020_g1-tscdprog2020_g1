# %%
#Creamos la clase Persona

class Persona:
    

    def __init__(self, dni_persona, nombre, apellido, sexo, nacimineto, telefono, direccion):
        self._dni = dni_persona
        self._nombre = nombre
        self._apellido = apellido
        self._sexo = sexo
        self._nacimiento = nacimineto
        self._telefono = telefono
        self._direccion = direccion

    def __str__(self):
        return (
            f"DNI: {self._dni}\n"
            f"Nombre: {self._nombre}\n"
            f"Apellido: {self._apellido}\n"
            f"Sexo: {self._sexo}\n"
            f"Fecha de Nacimineto: {self._nacimiento}\n"
            f"Numero de Telefono: {self._telefono}\n"
            f"Dirección: {self._direccion}\n"
            )
            

    
    def dni(self):
        return self._dni

   
    def dni(self, dni_persona):
        self._dni = dni_persona

    
    def nombre(self):
        return self._nombre

    
    def nombre(self, nombre):
        self._nombre = nombre

   
    def apellido(self):
        return self._apellido

    
    def apellido(self, apellido):
        self._apellido = apellido

    
    def sexo(self):
        return self._sexo

    
    def sexo(self, sexo):
        self._sexo = sexo

    
    def nacimiento(self):
        return self._nacimiento

    
    def nacimiento(self, nacimiento):
        self._nacimiento = nacimiento
        
    def telefono(self, telefono):
        self._telefono = telefono
        
    def direccion(self, direccion):
        self._direccion = direccion



if __name__ == '__main__':
    p1 = Persona(
        25678351,
        'Mariela',
        'Montero',
        'F',
        '05/04/1983',
        '351-5578999',
        'Santa Rosa 345 - Cordoba'
    )
    
    p2 = Persona(
         29948523,
        'Gabriel',
        'Medina',
        'M',
        '30/07/2018',
        '351-3456378',
        'Colon 1355 - Cordoba'
    )

    print("==================================")
    print(p1)
    print("==================================","\n")
    print(p2)
    print("==================================")
# Out:
# ...
# DNI: 25678351
# Nombre: Mariela
# Apellido: Montero
# Sexo: F
# Fecha de Nacimineto: 05/04/1983
# Numero de Telefono: 351-5578999
# Dirección: Santa Rosa 345 - Cordoba
#
# ...
#
# DNI: 29948523
# Nombre: Gabriel
# Apellido: Medina
# Sexo: M
# Fecha de Nacimineto: 30/07/2018
# Numero de Telefono: 351-3456378
# Dirección: Colon 1355 - Cordoba
#
# ...
