# %%
from colorama import init, Fore, Back, Style
import os
import time 
import pyttsx3
import pymysql



try:
	conexion = pymysql.connect(host='127.0.0.1',
                             user='root',
                             password='',
                             db='employees')
	print("Se Establecio Conexión correcta con la Base de Datos")
except (pymysql.err.OperationalError, pymysql.err.InternalError) as e:
	print("Ocurrió un error al conectar: ", e)
    
   
    
    
if os.name == "posix":
        var = "clear"      
elif os.name == "ce" or os.name == "nt" or os.name == "dos":
        var = "cls"
    
time.sleep(1)
os.system(var) 
print(Fore.BLUE +"****************************************") 
print("*                                      *")
print("*     BANCON - TU BANCO DIGITAL        *")
print("*                                      *")
print(Fore.BLUE +"****************************************")
    
time.sleep(2)
os.system(var)
    
print(Fore.BLUE +"****************************************")
print("*                                      *")
print("*TE PRESENTAMOS TU NUEVO BANCO DIGITAL *")
print("*                                      *")
print(Fore.BLUE +"****************************************")
    
    
    
#Creamos la clase cliente
    
class Cliente():
    def __init__(self, nombre, apellido, dni, telefono, dirección, ciudad, codigo, mail): #Aqui definimos los atributos de la clase cliente\n",
        #self.cliente = cliente
        self.nombre = nombre.capitalize()
        self.apellido = apellido.capitalize()
        self.dni = dni
        self.telefono = telefono
        self.dirección = dirección.capitalize()
        self.ciudad = ciudad.capitalize()
        self.codigo = codigo 
        self.mail = mail
        self.monto = 1000 
    
    def __str__(self):
        return(f"Nombre: {self.nombre}\n"
                f"Apellido: {self.apellido}\n"
                f"DNI: {self.dni}\n"
                f"Telefono: {self.telefono}\n"
                f"Dirección: {self.dirección}\n"
                f"Ciudad: {self.ciudad}\n"
                f"Codigo Postal: {self.codigo}\n"
                f"Mail: {self.mail}\n"
                )
        


#creamos la clase Banco 
class Banco():
  
    def __init__(self):
        self.usuarios = []
   
    def agregar_cliente(self):
          
            print("***********************************************")
            nombre = input("Digite el Nombre del usuario: ")
            apellido = input("Digite el Apellido del usuario: ")
            dni = int(input("Digite el DNI del usuario: "))
            telefono = int(input("Ingrese el Numero de telefono: "))
            dirección = (input ("Ingresar Dirección: "))
            ciudad = (input("Ingresar Ciudad: "))
            codigo = int(input("Ingresar Codigo Postal: "))
            mail = input("Ingresar Mail: ")
            print("**********************************************")
    
            if self.buscar_por_dni(dni):
                print("*********************************************************")
                print("\n*PRECAUCÍON * Ya existe un usuario con el mismo DNI **")
                print("*********************************************************")
            else:
                self.usuarios.append(Cliente(nombre, apellido, dni, telefono, dirección, ciudad, codigo, mail ))
                
    
    def buscar_por_dni(self, dni):
            for usuario in self.usuarios:
                if usuario.dni == dni:
                    return usuario
  
    
        
    def eliminar_por_dni(self, dni):
            cont=0
            for usuario in self.usuarios:
                if usuario.dni == dni:
                    del self.usuarios[cont] 
                    print("Usuario Eliminado")
                else:
                    cont+=[1]
                    
                        
    def mostrar_cliente(self, dni):
            cliente = self.buscar_por_dni(dni)
            if cliente:
                print("\n", cliente)
            else:
                print("***************************************************")
                print("\nNo existe un cliente con el DNI seleccionado")
                print("***************************************************")    
                return 
            

def main():
    time.sleep(1)
    os.system(var)
    banco = Banco()
     
    print(Fore.BLUE +"**************************************************")
    print("\n**   BIENVENIDO AL BANCO SUCURSAL 444 CÓRDOBA **\n")
    print(Fore.BLUE +"**************************************************")
    while True:
        try:
            print(Fore.BLUE +"****************************************")
            print("*                                      *")
            print("*         MENU PRINCIPAL               *")
            print("*                                      *")
            print(Fore.BLUE +"****************************************")
            print("\nDigite una opcion: \n\n"
             
                      "  1) Agregar usuario\n"
                      "  2) Visualizar usuario\n"
                      "  3) Eliminar usuario\n"
                      #"  4) Generar Deposito\n"
                      #"  5) Extracción Caja de Ahorro\n"
                      #"  6) Realizar Plazo Fijo\n"
                      "  7) Salir")

            opcion = input("\nDigite una opcion: ")
              
            if opcion == "1":
                banco.agregar_cliente()
                    
            elif opcion == "2":
                engine = pyttsx3.init()
                # Control the rate. Higher rate = more speed
                engine.setProperty("rate", 130)
                text1 = "Estamos para Ayudarte"
                text = "Por favor Ingresar numero de DNI"
                engine.say(text1)
                engine.say(text)
                """
                #Queue another audio
                """
                another_text = "Bancón tu mundo digital"
                engine.say(another_text)
                engine.runAndWait()
                dni = int(input("\nDigite el DNI del usuario que desea buscar: "))
                print("======================================================")
                banco.mostrar_cliente(dni)
                print("======================================================")
                    
            elif opcion =="3": 
                
                    dni = int(input("\nIngrese DNI del Usuario a Eliminar: "))
                    banco.eliminar_por_dni(dni)
                
            elif opcion =="4": 
                    
                    dni = (input("Ingrese su numero de DNI:"))
                    #banco.mostrar_cliente(dni)
                    banco.buscar_por_dni(dni)
                     
                    
                    
            elif opcion =="5": 
                    print("**************************************************************")
                    extraer = float(input("Cuanto dinero desea extrer de su cuenta -> $"))
                    if extraer > saldo:
                        print("\n")
                        print("El Saldo en su Cuenta Caja de Ahorro es insuficiente")
                        print("**************************************************************")
                    else:
                        saldo = saldo - extraer
                        print("\n")
                        print(f"El Saldo de dinero en su cuenta Caja de Ahorro es: $", saldo,)
                        print("***********************************************************")
                           
            elif opcion =="6":
                
                  
                print(input("Ingrese DNI para realizar un Plazo FIJO"))
                #print(f"Se abrio la cuenta {self.numero} a nombre de {self.cliente},el dia {self.fecha_apertura}")
                monto=0
                #saldo=0
                if monto < 0:
                    print(" el monto no puede ser negativo")
                else:
                    monto += self.monto
                    #return cuenta
                    print("EL Monto en su Plazo Fijo es: ", self.monto)
    
            elif opcion =="7":
                        quit()
                        print("*************************************************************************")
                        print( "** Gracias por Utilizar Nuestros Servicios - Bancon - Tu Banco Digital **")
                        print("*************************************************************************")
                        
        except ValueError:
            print("\nOpción Incorrecta...... Intentelo Nuevamente")
               
if __name__=='__main__':            
    main();
# Out:
# Se Establecio Conexión correcta con la Base de Datos
# ****************************************
# *                                      *
# *     BANCON - TU BANCO DIGITAL        *
# *                                      *
# ****************************************
# ****************************************
# *                                      *
# *TE PRESENTAMOS TU NUEVO BANCO DIGITAL *
# *                                      *
# ****************************************
# **************************************************
#
# **   BIENVENIDO AL BANCO SUCURSAL 444 CÓRDOBA **
#
# **************************************************
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   7) Salir
#
# Digite una opcion: 1
# ***********************************************
# Digite el Nombre del usuario: 1
# Digite el Apellido del usuario: medina
# Digite el DNI del usuario: jorge
#
# Opción Incorrecta...... Intentelo Nuevamente
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   7) Salir
#
# Digite una opcion: 1
# ***********************************************
# Digite el Nombre del usuario: jorge
# Digite el Apellido del usuario: medina
# Digite el DNI del usuario: 25320444
# Ingrese el Numero de telefono: 03513866604
# Ingresar Dirección: Avenida Colon 1457
# Ingresar Ciudad: Cordoba
# Ingresar Codigo Postal: 5000
# Ingresar Mail: turaca@hotmail.com
# **********************************************
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   7) Salir
#
# Digite una opcion: 2
#
# Digite el DNI del usuario que desea buscar: 25320444
# ======================================================
#
#  Nombre: Jorge
# Apellido: Medina
# DNI: 25320444
# Telefono: 3513866604
# Dirección: Avenida colon 1457
# Ciudad: Cordoba
# Codigo Postal: 5000
# Mail: turaca@hotmail.com
#
# ======================================================
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   7) Salir
#
# Digite una opcion: 3
#
# Ingrese DNI del Usuario a Eliminar: 25320444
# Usuario Eliminado
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   7) Salir
#
# Digite una opcion: 2
#
# Digite el DNI del usuario que desea buscar: 25320444
# ======================================================
# ***************************************************
#
# No existe un cliente con el DNI seleccionado
# ***************************************************
# ======================================================
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   7) Salir
#
# Digite una opcion: 7
# *************************************************************************
# ** Gracias por Utilizar Nuestros Servicios - Bancon - Tu Banco Digital **
# *************************************************************************
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   7) Salir

# %%
pip install pyttsx3
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Conexión correcta

# %%
import pymysql


class Conexion:
    
    def __init__(self):
        self.host='localhost'
        self.user='root'
        self.password=''
        self.db='employees'
        
        
    def conectar(self):
        try:
            conexion = pymysql.connect(host=self.host,
                                    user=self.user,
                                    password=self.password,
                                    db=self.db)
            return conexion   

        except (pymysql.err.OperationalError, pymysql.err.InternalError) as e:
            print("Ocurrió un error al conectar: ", e)

# %%
# Out:
#   File "<ipython-input-13-abdf5c98dc20>", line 2
#     sql = str(sql)
#     ^
# IndentationError: unexpected indent
