# %%
from colorama import init, Fore, Back, Style
import os
import time 
import pyttsx3
    
if os.name == "posix":
        var = "clear"      
elif os.name == "ce" or os.name == "nt" or os.name == "dos":
        var = "cls"
    
time.sleep(1)
os.system(var) 
print(Fore.BLUE +"****************************************") 
print("*                                      *")
print("*     BANCON - TU BANCO DIGITAL        *")
print("*                                      *")
print(Fore.BLUE +"****************************************")
    
time.sleep(2)
os.system(var)
    
print(Fore.BLUE +"****************************************")
print("*                                      *")
print("*TE PRESENTAMOS TU NUEVO BANCO DIGITAL *")
print("*                                      *")
print(Fore.BLUE +"****************************************")
    
    
    
#Creamos la clase cliente
    
class Cliente():
    def __init__(self, nombre, apellido, dni, telefono, dirección, ciudad, codigo, mail): #Aqui definimos los atributos de la clase cliente\n",
        #self.cliente = cliente
        self.nombre = nombre.capitalize()
        self.apellido = apellido.capitalize()
        self.dni = dni
        self.telefono = telefono
        self.dirección = dirección.capitalize()
        self.ciudad = ciudad.capitalize()
        self.codigo = codigo 
        self.mail = mail
        self.monto = 0 
    
    def __str__(self):
        return(f"Nombre: {self.nombre}\n"
                f"Apellido: {self.apellido}\n"
                f"DNI: {self.dni}\n"
                f"Telefono: {self.telefono}\n"
                f"Dirección: {self.dirección}\n"
                f"Ciudad: {self.ciudad}\n"
                f"Codigo Postal: {self.codigo}\n"
                f"Mail: {self.mail}\n"
                )
        
class cuenta():
    total_abiertas = 0 
    existentes = dict()
        
      
    def __init__(self, cliente):
           
        cuenta.total_abiertas += 1
        #self.cliente = cliente
        self.dni = dni
        self.saldo = 0 
        self.numero = f"PLAZO FIJO {cuenta.total_abiertas:04d}"
        self.fecha_apertura = datetime.now()
        cuenta.existentes[self.numero] = self
        print(f"Se abrio la cuenta {self.numero} a nombre de {self.cliente},el dia {self.fecha_apertura}")
 
#repr nos permite imprimir plazo fijo,nombre del cliente y el saldo en la cuenta
    def __repr__(self): 
        return (f"Cuenta {self.numero}, cliente {self.cliente}, saldo = {self.saldo}")


    def depositar(self, monto):
        if monto < 0:
            print(" el monto no puede ser negativo")
        else:
            self.saldo += monto
            print(f"Se deposito {monto} en la cuenta {self.numero} a nombre de {self.cliente} Su saldo es {self.saldo}")
          
    def retirar(self, monto):
        if monto < 0:
            print("el monto no puede ser negativo")
        elif monto > self.saldo:
            print("Fondos Insuficientes")
                   
        else:
            self.saldo -= monto
            print(f"Se Retiro {monto} de la cuenta {self.numero}. Su saldo es {self.saldo}")
           
    def transferir(self, monto, otra_cuenta):
        if monto < 0:
            print("el monto no puede ser negativo")
        elif monto > self.saldo:
            print("Fondos Insuficientes")
        if otra_cuenta not in cuenta.existentes:
            print("La cuenta destino no existe")
        else:
            self.saldo -= monto
            cuenta.existentes[otra_cuenta].saldo += monto
            print(f"Se realizo la transferencia {monto} de la cuenta {self.numero}. a la cuenta {otra_cuenta}")
     
#creamos la clase Banco 
class Banco(cuenta):
  
    def __init__(self):
        self.usuarios = []
   
    def agregar_cliente(self):
          
            print("***********************************************")
            nombre = input("Digite el Nombre del usuario: ")
            apellido = input("Digite el Apellido del usuario: ")
            dni = int(input("Digite el DNI del usuario: "))
            telefono = int(input("Ingrese el Numero de telefono: "))
            dirección = (input ("Ingresar Dirección "))
            ciudad = (input("Ingresar Ciudad"))
            codigo = int(input("Ingresar Codigo Postal"))
            mail = input("Ingresar Mail")
            print("**********************************************")
    
            if self.buscar_por_dni(dni):
                print("*********************************************************")
                print("\n*PRECAUCÍON * Ya existe un usuario con el mismo DNI **")
                print("*********************************************************")
            else:
                self.usuarios.append(Cliente(nombre, apellido, dni, telefono, dirección, ciudad, codigo, mail ))
                
    
    def buscar_por_dni(self, dni):
            for usuario in self.usuarios:
                if usuario.dni == dni:
                    return usuario
  
        #Eliminar por dni
        
    def eliminar_por_dni(self, dni):
            cont=0
            for usuario in self.usuarios:
                if usuario.dni == dni:
                    del self.usuarios[cont] 
                    print("Usuario Eliminado")
                else:
                    cont+=[1]
                    
                        
    def mostrar_cliente(self, dni):
            cliente = self.buscar_por_dni(dni)
            if cliente:
                print("\n", cliente)
            else:
                print("***************************************************")
                print("\nNo existe un cliente con el DNI seleccionado")
                print("***************************************************")    
                return 
    
def main():
    time.sleep(1)
    os.system(var)
    banco = Banco()
     
    print(Fore.BLUE +"**************************************************")
    print("\n**   BIENVENIDO AL BANCO SUCURSAL 444 CÓRDOBA **\n")
    print(Fore.BLUE +"**************************************************")
    while True:
        try:
            print(Fore.BLUE +"****************************************")
            print("*                                      *")
            print("*         MENU PRINCIPAL               *")
            print("*                                      *")
            print(Fore.BLUE +"****************************************")
            print("\nDigite una opcion: \n\n"
             
                      "  1) Agregar usuario\n"
                      "  2) Visualizar usuario\n"
                      "  3) Eliminar usuario\n"
                      "  4) Generar Deposito\n"
                      "  5) Extracción Caja de Ahorro\n"
                      "  6) Realizar Plazo Fijo\n"
                      "  7) Salir")

            opcion = input("\nDigite una opcion: ")
              
            if opcion == "1":
                banco.agregar_cliente()
                    
            elif opcion == "2":
                engine = pyttsx3.init()
                # Control the rate. Higher rate = more speed
                engine.setProperty("rate", 130)
                text1 = "Estamos para Ayudarte"
                text = "Por favor Ingresar numero de DNI"
                engine.say(text1)
                engine.say(text)
                """
                #Queue another audio
                """
                another_text = "Bancón tu mundo digital"
                engine.say(another_text)
                engine.runAndWait()
                dni = int(input("\nDigite el DNI del usuario que desea buscar: "))
                print("======================================================")
    
                          #print("El usuario Corresponde al Cliente:) 
                banco.mostrar_cliente(dni)
                
                    #if dni != dni:
                       # return mostrar_cliente(self, dni)
                print("======================================================")
                    
            elif opcion =="3": 
                  
                dni = int(input("\nIngrese DNI del Usuario a Eliminar: "))
                print("======================================================")
                if banco.eliminar_por_dni(dni) == dni:
                        return buscar_por_dni(dni) 
                else:
                        banco.mostrar_cliente(dni)
                        print("======================================================")
                  
            elif opcion =="4": 
                    print("****************************************************************")
                    print(input("Ingrese su numero de DNI:"))
                    print("****************************************************************\n")
                    if cliente!= dni: 
                            print("El cliente no existe")
                                 
                    else:
                            #banco.mostrar_cliente(dni)
                            #print("El cliente no existe")
                       # return main()
                        deposito = float(input("Cuanto dinero desea depositar en su cuenta -> $"))
                        monto = 15000
                        saldo = monto + deposito 
                        #print("\n")
                     
                        print(f"El dinero se acredito correctamente - Su Saldo es: $", saldo)
                        print("****************************************************************")
                        print("\n")
                        #return main()
            elif opcion =="5": 
                    print("**************************************************************")
                    extraer = float(input("Cuanto dinero desea extrer de su cuenta -> $"))
                    if extraer > saldo:
                        print("\n")
                        print("El Saldo en su Cuenta Caja de Ahorro es insuficiente")
                        print("**************************************************************")
                    else:
                        saldo = saldo - extraer
                        print("\n")
                        print(f"El Saldo de dinero en su cuenta Caja de Ahorro es: $", saldo,)
                        print("***********************************************************")
                           
            elif opcion =="6":
                
                  
                print(input("Ingrese DNI para realizar un Plazo FIJO"))
                #print(f"Se abrio la cuenta {self.numero} a nombre de {self.cliente},el dia {self.fecha_apertura}")
                monto=0
                if monto < 0:
                    print(" el monto no puede ser negativo")
                else:
                    self.saldo += monto
                    return cuenta
    
            elif opcion =="7":
                        quit()
                        print("*************************************************************************")
                        print( "** Gracias por Utilizar Nuestros Servicios - Bancon - Tu Banco Digital **")
                        print("*************************************************************************")
                        
        except ValueError:
            print("\\nOpción incorrecta, intentelo nuevamente")
               
if __name__=='__main__':            
    main()
# Out:
# ****************************************
# *                                      *
# *     BANCON - TU BANCO DIGITAL        *
# *                                      *
# ****************************************
# ****************************************
# *                                      *
# *TE PRESENTAMOS TU NUEVO BANCO DIGITAL *
# *                                      *
# ****************************************
# **************************************************
#
# **   BIENVENIDO AL BANCO SUCURSAL 444 CÓRDOBA **
#
# **************************************************
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   4) Generar Deposito
#   5) Extracción Caja de Ahorro
#   6) Realizar Plazo Fijo
#   7) Salir
#
# Digite una opcion: 2
#
# Digite el DNI del usuario que desea buscar: 25320444
# ======================================================
# ***************************************************
#
# No existe un cliente con el DNI seleccionado
# ***************************************************
# ======================================================
# ****************************************
# *                                      *
# *         MENU PRINCIPAL               *
# *                                      *
# ****************************************
#
# Digite una opcion:
#
#   1) Agregar usuario
#   2) Visualizar usuario
#   3) Eliminar usuario
#   4) Generar Deposito
#   5) Extracción Caja de Ahorro
#   6) Realizar Plazo Fijo
#   7) Salir
